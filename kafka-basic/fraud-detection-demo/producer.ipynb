# %%
from kafka import KafkaProducer
import json
import time
import random
producer = KafkaProducer(
 bootstrap_servers=['kafka:9092'],
 value_serializer=lambda v: json.dumps(v).encode('utf-8')
)
user_ids = [101, 102, 103, 104, 105]
print("Starting Transaction Producer...")
for i in range(100):
 tx_data = {
 "tx_id": i,
 "userId": random.choice(user_ids),
 "amount": random.uniform(10.0, 15000.0), # >10000 triggers fraud
 "timestamp": time.time()
 }
 producer.send('fraud-detection', value=tx_data)
 print(f"Sent: {tx_data}")
 time.sleep(2)
# Out:
# Starting Transaction Producer...
# Sent: {'tx_id': 0, 'userId': 102, 'amount': 11411.83301997883, 'timestamp': 1781849591.771765}
# Sent: {'tx_id': 1, 'userId': 105, 'amount': 8287.773741694535, 'timestamp': 1781849593.9836786}
# Sent: {'tx_id': 2, 'userId': 101, 'amount': 11691.872283494773, 'timestamp': 1781849595.9848049}
# Sent: {'tx_id': 3, 'userId': 105, 'amount': 8886.077731996633, 'timestamp': 1781849597.9852254}
# Sent: {'tx_id': 4, 'userId': 101, 'amount': 2476.2075808173176, 'timestamp': 1781849599.985738}
# Sent: {'tx_id': 5, 'userId': 103, 'amount': 10765.363404745452, 'timestamp': 1781849601.9862192}
# Sent: {'tx_id': 6, 'userId': 104, 'amount': 11706.367068883526, 'timestamp': 1781849603.9875355}
# Sent: {'tx_id': 7, 'userId': 101, 'amount': 8170.472616046847, 'timestamp': 1781849605.9886873}
# Sent: {'tx_id': 8, 'userId': 103, 'amount': 11495.010136532717, 'timestamp': 1781849607.9901123}
# Sent: {'tx_id': 9, 'userId': 103, 'amount': 14933.411017869948, 'timestamp': 1781849609.9917614}
# Sent: {'tx_id': 10, 'userId': 104, 'amount': 8886.855271652532, 'timestamp': 1781849611.9922318}
# Sent: {'tx_id': 11, 'userId': 104, 'amount': 3396.80327745249, 'timestamp': 1781849613.9927242}
# Sent: {'tx_id': 12, 'userId': 103, 'amount': 358.55585381178247, 'timestamp': 1781849615.9938226}
# Sent: {'tx_id': 13, 'userId': 105, 'amount': 12527.662868715626, 'timestamp': 1781849617.995332}
# Sent: {'tx_id': 14, 'userId': 101, 'amount': 8380.844195032274, 'timestamp': 1781849619.9966543}
# Sent: {'tx_id': 15, 'userId': 103, 'amount': 10641.99435331424, 'timestamp': 1781849621.9971092}
# Sent: {'tx_id': 16, 'userId': 102, 'amount': 3961.349311817558, 'timestamp': 1781849623.9977472}
# Sent: {'tx_id': 17, 'userId': 105, 'amount': 3984.8089444157845, 'timestamp': 1781849625.9988139}
# Sent: {'tx_id': 18, 'userId': 101, 'amount': 13275.737990445406, 'timestamp': 1781849627.999317}
# Sent: {'tx_id': 19, 'userId': 105, 'amount': 14365.518359722624, 'timestamp': 1781849630.000916}
# Sent: {'tx_id': 20, 'userId': 103, 'amount': 6367.644744628578, 'timestamp': 1781849632.00199}
# Sent: {'tx_id': 21, 'userId': 102, 'amount': 3761.567546421989, 'timestamp': 1781849634.002532}
# Sent: {'tx_id': 22, 'userId': 105, 'amount': 641.796577059905, 'timestamp': 1781849636.0037272}
# Sent: {'tx_id': 23, 'userId': 103, 'amount': 12963.371220495324, 'timestamp': 1781849638.0050673}
# Sent: {'tx_id': 24, 'userId': 105, 'amount': 429.83196372102674, 'timestamp': 1781849640.00554}
# Sent: {'tx_id': 25, 'userId': 104, 'amount': 9754.106307523376, 'timestamp': 1781849642.0069609}
# Sent: {'tx_id': 26, 'userId': 105, 'amount': 14665.624910791517, 'timestamp': 1781849644.007436}
# Sent: {'tx_id': 27, 'userId': 102, 'amount': 3746.628757303362, 'timestamp': 1781849646.0087965}
# Sent: {'tx_id': 28, 'userId': 101, 'amount': 10287.358267068295, 'timestamp': 1781849648.0100956}
# Sent: {'tx_id': 29, 'userId': 102, 'amount': 13266.02867242778, 'timestamp': 1781849650.010576}
# Sent: {'tx_id': 30, 'userId': 105, 'amount': 7372.696208643239, 'timestamp': 1781849652.0119853}
# Sent: {'tx_id': 31, 'userId': 103, 'amount': 2025.0779520054912, 'timestamp': 1781849654.0125113}
# Sent: {'tx_id': 32, 'userId': 101, 'amount': 9419.57725971061, 'timestamp': 1781849656.0136454}
# Sent: {'tx_id': 33, 'userId': 105, 'amount': 4657.266101900874, 'timestamp': 1781849658.0142794}
# Sent: {'tx_id': 34, 'userId': 105, 'amount': 9760.677265066868, 'timestamp': 1781849660.0156953}
# Sent: {'tx_id': 35, 'userId': 102, 'amount': 10851.251427411387, 'timestamp': 1781849662.0174294}
# Sent: {'tx_id': 36, 'userId': 102, 'amount': 1587.8869025901608, 'timestamp': 1781849664.0178633}
# Sent: {'tx_id': 37, 'userId': 105, 'amount': 4745.558623250313, 'timestamp': 1781849666.018359}
# Sent: {'tx_id': 38, 'userId': 102, 'amount': 3187.8509215611234, 'timestamp': 1781849668.0190582}
# Sent: {'tx_id': 39, 'userId': 101, 'amount': 14724.538712646858, 'timestamp': 1781849670.0195885}
# Sent: {'tx_id': 40, 'userId': 105, 'amount': 9497.50877319523, 'timestamp': 1781849672.0200424}
# Sent: {'tx_id': 41, 'userId': 103, 'amount': 2745.358348949593, 'timestamp': 1781849674.0231225}
# Sent: {'tx_id': 42, 'userId': 105, 'amount': 13043.505465908462, 'timestamp': 1781849676.0235834}
# Sent: {'tx_id': 43, 'userId': 101, 'amount': 5078.574206293571, 'timestamp': 1781849678.0240538}
# Sent: {'tx_id': 44, 'userId': 105, 'amount': 9343.99656033502, 'timestamp': 1781849680.0257976}
# Sent: {'tx_id': 45, 'userId': 101, 'amount': 866.1073246307686, 'timestamp': 1781849682.0262477}
# Sent: {'tx_id': 46, 'userId': 104, 'amount': 11245.095812516282, 'timestamp': 1781849684.026701}
# Sent: {'tx_id': 47, 'userId': 103, 'amount': 625.9498496612575, 'timestamp': 1781849686.02711}
# Sent: {'tx_id': 48, 'userId': 105, 'amount': 3715.4623277363985, 'timestamp': 1781849688.027546}
# Sent: {'tx_id': 49, 'userId': 101, 'amount': 2963.9220496807047, 'timestamp': 1781849690.0279794}
# Sent: {'tx_id': 50, 'userId': 105, 'amount': 7972.913332342334, 'timestamp': 1781849692.0284405}
# Sent: {'tx_id': 51, 'userId': 104, 'amount': 2961.303321156868, 'timestamp': 1781849694.0289495}
# Sent: {'tx_id': 52, 'userId': 104, 'amount': 6088.984558880705, 'timestamp': 1781849696.0294}
# Sent: {'tx_id': 53, 'userId': 102, 'amount': 14400.298589491596, 'timestamp': 1781849698.0298162}
# Sent: {'tx_id': 54, 'userId': 103, 'amount': 14217.920531904272, 'timestamp': 1781849700.0302672}
# Sent: {'tx_id': 55, 'userId': 103, 'amount': 4155.588474716144, 'timestamp': 1781849702.0321121}
# Sent: {'tx_id': 56, 'userId': 102, 'amount': 10327.639008355292, 'timestamp': 1781849704.0325506}
# Sent: {'tx_id': 57, 'userId': 104, 'amount': 7733.6257785343705, 'timestamp': 1781849706.033008}
# Sent: {'tx_id': 58, 'userId': 103, 'amount': 237.16407888545925, 'timestamp': 1781849708.03348}
# Sent: {'tx_id': 59, 'userId': 105, 'amount': 11042.468515883762, 'timestamp': 1781849710.033931}
# Sent: {'tx_id': 60, 'userId': 104, 'amount': 1012.038678227449, 'timestamp': 1781849712.0343816}
# Sent: {'tx_id': 61, 'userId': 101, 'amount': 14555.492887852603, 'timestamp': 1781849714.0348296}
# Sent: {'tx_id': 62, 'userId': 101, 'amount': 3997.2816867222878, 'timestamp': 1781849716.0353703}
# Sent: {'tx_id': 63, 'userId': 104, 'amount': 9782.554587782497, 'timestamp': 1781849718.0371113}
# Sent: {'tx_id': 64, 'userId': 104, 'amount': 13597.30930179457, 'timestamp': 1781849720.037579}
# Sent: {'tx_id': 65, 'userId': 105, 'amount': 14169.052164227602, 'timestamp': 1781849722.0380104}
# Sent: {'tx_id': 66, 'userId': 102, 'amount': 901.0027922276181, 'timestamp': 1781849724.038481}
# Sent: {'tx_id': 67, 'userId': 101, 'amount': 7427.7017429258585, 'timestamp': 1781849726.0389268}
# Sent: {'tx_id': 68, 'userId': 104, 'amount': 5904.495141467538, 'timestamp': 1781849728.0394058}
# Sent: {'tx_id': 69, 'userId': 104, 'amount': 10467.639310825694, 'timestamp': 1781849730.039884}
# Sent: {'tx_id': 70, 'userId': 101, 'amount': 447.22203169822876, 'timestamp': 1781849732.0421169}
# Sent: {'tx_id': 71, 'userId': 102, 'amount': 9226.357680075924, 'timestamp': 1781849734.043709}
# Sent: {'tx_id': 72, 'userId': 103, 'amount': 9145.992216114118, 'timestamp': 1781849736.045116}
# Sent: {'tx_id': 73, 'userId': 105, 'amount': 14127.307719993456, 'timestamp': 1781849738.0456295}
# Sent: {'tx_id': 74, 'userId': 101, 'amount': 14459.368033546809, 'timestamp': 1781849740.046274}
# Sent: {'tx_id': 75, 'userId': 104, 'amount': 962.9803304972544, 'timestamp': 1781849742.0474517}
# Sent: {'tx_id': 76, 'userId': 105, 'amount': 11619.068747221325, 'timestamp': 1781849744.0480719}
# Sent: {'tx_id': 77, 'userId': 101, 'amount': 11128.882064083602, 'timestamp': 1781849746.0485902}
# Sent: {'tx_id': 78, 'userId': 103, 'amount': 8699.304836442005, 'timestamp': 1781849748.049209}
# Sent: {'tx_id': 79, 'userId': 101, 'amount': 2790.1216332458016, 'timestamp': 1781849750.049599}
# Sent: {'tx_id': 80, 'userId': 101, 'amount': 8179.984130404099, 'timestamp': 1781849752.0510693}
# Sent: {'tx_id': 81, 'userId': 102, 'amount': 9051.677167472282, 'timestamp': 1781849754.05152}
# Sent: {'tx_id': 82, 'userId': 104, 'amount': 11407.77027417629, 'timestamp': 1781849756.0519264}
# Sent: {'tx_id': 83, 'userId': 103, 'amount': 9832.656151903491, 'timestamp': 1781849758.054077}
# Sent: {'tx_id': 84, 'userId': 105, 'amount': 306.26581636502596, 'timestamp': 1781849760.0555935}
# Sent: {'tx_id': 85, 'userId': 104, 'amount': 11439.170450730253, 'timestamp': 1781849762.056097}
# Sent: {'tx_id': 86, 'userId': 103, 'amount': 1164.7060477066364, 'timestamp': 1781849764.056601}
# Sent: {'tx_id': 87, 'userId': 104, 'amount': 1678.2746804553462, 'timestamp': 1781849766.0579538}
# Sent: {'tx_id': 88, 'userId': 104, 'amount': 3485.952479683057, 'timestamp': 1781849768.0584602}
# Sent: {'tx_id': 89, 'userId': 104, 'amount': 11441.670536607242, 'timestamp': 1781849770.0590515}
# Sent: {'tx_id': 90, 'userId': 103, 'amount': 6482.120969032483, 'timestamp': 1781849772.059553}
# Sent: {'tx_id': 91, 'userId': 102, 'amount': 14583.1658091896, 'timestamp': 1781849774.0602896}
# Sent: {'tx_id': 92, 'userId': 103, 'amount': 4925.622945669425, 'timestamp': 1781849776.0607278}
# Sent: {'tx_id': 93, 'userId': 104, 'amount': 1324.572143554166, 'timestamp': 1781849778.062116}
# Sent: {'tx_id': 94, 'userId': 104, 'amount': 14040.47876898878, 'timestamp': 1781849780.0625505}
# Sent: {'tx_id': 95, 'userId': 105, 'amount': 7501.601178716954, 'timestamp': 1781849782.0630414}
# Sent: {'tx_id': 96, 'userId': 103, 'amount': 3020.472596356696, 'timestamp': 1781849784.0637264}
# Sent: {'tx_id': 97, 'userId': 104, 'amount': 7010.765034529451, 'timestamp': 1781849786.0642028}
# Sent: {'tx_id': 98, 'userId': 104, 'amount': 9862.628486467425, 'timestamp': 1781849788.0647233}
# Sent: {'tx_id': 99, 'userId': 104, 'amount': 10795.39847555241, 'timestamp': 1781849790.0652258}
